# %% [markdown]
# # DATA EXPLORATION USING PANDAS

# %% [markdown]
# ## ABOUT THE DATASET

# %% [markdown]
# ## This dataset is downloaded from the Kaggle dataset website and used it to do some basic data exploration using pandas.This dataset contains the Marks secured by the students in various subjects.

# %%
import pandas as pd

# %% [markdown]
# #### To perform the operations we need to import a library, so here pandas library is imported locally as pd

# %%
StudentsPerformance=pd.read_csv("D:\Python\StudentsPerformance.csv")

# %% [markdown]
# #### Use pd.read_csv function to read the dataset in to Jupyter Notebook

# %%
StudentsPerformance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math score  reading score  writing score
# ...

# %% [markdown]
# #### To view the read dataset, use the dataset name Students Performance.

# %%
StudentsPerformance.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test_preparation_course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %% [markdown]
# #### The First ten observations of dataset.

# %%
StudentsPerformance.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %% [markdown]
# #### The last five observations of dataset.

# %%
StudentsPerformance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# #### To know the variables and its data type.

# %%
StudentsPerformance.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# #### Basic statistics

# %%
StudentsPerformance.count()
# Out:
# gender                         1000
# race/ethnicity                 1000
# parental level of education    1000
# lunch                          1000
# test_preparation_course        1000
# math score                     1000
# reading score                  1000
# writing score                  1000
# dtype: int64

# %% [markdown]
# #### 1000 observations in each variable.

# %%
StudentsPerformance.shape
# Out:
# (1000, 8)

# %% [markdown]
# ####  1000 observations and 12 variables.

# %%
StudentsPerformance.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %% [markdown]
# #### RangeIndex starts from 0 and ends in 1000.

# %%
StudentsPerformance.sort_values(['race/ethnicity'],ascending=True)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 778  female        group A                some college      standard
# 546  female        group A            some high school      standard
# 820  female        group A            some high school      standard
# 741  female        group A          associate's degree  free/reduced
# 305    male        group A                some college      standard
# ..      ...            ...                         ...           ...
# 297    male        group E          associate's degree      standard
# 293  female        group E           bachelor's degree      standard
# 289    male        group E            some high school      standard
# 206    male        group E           bachelor's degree      standard
# 499    male        group E                some college      standard
#
#     test_preparation_course  math score  reading score  writing score
# ...

# %% [markdown]
# ####   Dataset is arranged ascending according to the race/ethnicity variable

# %%
StudentsPerformance['test_preparation_course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test_preparation_course, dtype: int64

# %% [markdown]
# #### Count of test preparation course in dataset

# %%
StudentsPerformance.drop_duplicates(inplace=True)

# %% [markdown]
# #### No duplicates found in the dataset

# %%
StudentsPerformance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math score  reading score  writing score
# ...

# %%
SPerformance=StudentsPerformance[['gender','race/ethnicity','math score','reading score','writing score']]

# %%
SPerformance
# Out:
#      gender race/ethnicity  math score  reading score  writing score
# 0    female        group B          72             72             74
# 1    female        group C          69             90             88
# 2    female        group B          90             95             93
# 3      male        group A          47             57             44
# 4      male        group C          76             78             75
# ..      ...            ...         ...            ...            ...
# 995  female        group E          88             99             95
# 996    male        group C          62             55             55
# 997  female        group C          59             71             65
# 998  female        group D          68             78             77
# 999  female        group D          77             86             86
#
# [1000 rows x 5 columns]

# %% [markdown]
# ####  Column subset dataset created

# %%
SPerformance_row=SPerformance[SPerformance['math score']<50]

# %%
SPerformance_row
# Out:
#      gender race/ethnicity  math score  reading score  writing score
# 3      male        group A          47             57             44
# 7      male        group B          40             43             39
# 9    female        group B          38             60             50
# 11     male        group D          40             52             43
# 17   female        group B          18             32             28
# ..      ...            ...         ...            ...            ...
# 961  female        group D          48             54             53
# 973  female        group D          49             65             61
# 980  female        group B           8             24             23
# 986  female        group C          40             59             51
# 988  female        group A          44             45             45
#
# [135 rows x 5 columns]

# %% [markdown]
# #### Row subset dataset created

# %%
StudentsPerformance['lan score']=StudentsPerformance['reading score']+StudentsPerformance['writing score']

# %%
StudentsPerformance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math score  reading score  writing score  \
# ...

# %%
StudentsPerformance['average']=StudentsPerformance['lan score']/2

# %%
StudentsPerformance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math score  reading score  writing score  \
# ...

# %% [markdown]
# #### Average of two variables calculated.

# %%
SPerformance_index=StudentsPerformance.set_index('race/ethnicity')

# %%
SPerformance_index
# Out:
#                 gender parental level of education         lunch  \
# race/ethnicity
# group B         female           bachelor's degree      standard
# group C         female                some college      standard
# group B         female             master's degree      standard
# group A           male          associate's degree  free/reduced
# group C           male                some college      standard
# ...                ...                         ...           ...
# group E         female             master's degree      standard
# group C           male                 high school  free/reduced
# group C         female                 high school  free/reduced
# group D         female                some college      standard
# group D         female                some college  free/reduced
#
#                test_preparation_course  math score  reading score  \
# race/ethnicity
# group B                           none          72             72
# ...

# %% [markdown]
# #####  Changing the default index position

# %%
SPerformance_index=SPerformance_index.reset_index()

# %%
SPerformance_index
# Out:
#     race/ethnicity  gender parental level of education         lunch  \
# 0          group B  female           bachelor's degree      standard
# 1          group C  female                some college      standard
# 2          group B  female             master's degree      standard
# 3          group A    male          associate's degree  free/reduced
# 4          group C    male                some college      standard
# ..             ...     ...                         ...           ...
# 995        group E  female             master's degree      standard
# 996        group C    male                 high school  free/reduced
# 997        group C  female                 high school  free/reduced
# 998        group D  female                some college      standard
# 999        group D  female                some college  free/reduced
#
#     test_preparation_course  math score  reading score  writing score  \
# ...

# %% [markdown]
# #####  Resetting the index position to default.

# %%
SPerformance_loc=StudentsPerformance.loc[(StudentsPerformance.gender=='female')&(StudentsPerformance.test_preparation_course=='completed')]

# %%
SPerformance_loc
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 1    female        group C                some college      standard
# 6    female        group B                some college      standard
# 21   female        group B                some college  free/reduced
# 38   female        group D          associate's degree  free/reduced
# 46   female        group A          associate's degree      standard
# ..      ...            ...                         ...           ...
# 989  female        group D                some college  free/reduced
# 991  female        group B            some high school      standard
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
#
#     test_preparation_course  math score  reading score  writing score  \
# ...

# %% [markdown]
# #### Locating a variable in dataset

# %%
StudentsPerformance_iloc=StudentsPerformance.iloc[0:3,0:5]

# %%
StudentsPerformance_iloc
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test_preparation_course
# 0                    none
# 1               completed
# 2                    none

# %% [markdown]
# ####  Locating data using integer position

# %%
StudentsPerformance_agg=StudentsPerformance.groupby("parental level of education")["math score"].mean()

# %%
StudentsPerformance_agg
# Out:
# parental level of education
# associate's degree    67.882883
# bachelor's degree     69.389831
# high school           62.137755
# master's degree       69.745763
# some college          67.128319
# some high school      63.497207
# Name: math score, dtype: float64

# %% [markdown]
# #### Groupby aggregate function

# %%
StudentsPerformance['average']=StudentsPerformance['average'].astype('object')

# %%
StudentsPerformance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
#  8   lan score                    1000 non-null   int64
#  9   average                      1000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 85.9+ KB

# %%
StudentsPerformance['average']=StudentsPerformance['average'].astype('int')

# %%
StudentsPerformance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
#  8   lan score                    1000 non-null   int64
#  9   average                      1000 non-null   int32
# dtypes: int32(1), int64(4), object(5)
# memory usage: 82.0+ KB

# %% [markdown]
# #### Datatype has been changed
